# %% [markdown]
# # Adder and Subtractor
# 回家記得改一下資料生成的方式，隨機產生 + -

# %%
from keras.models import Sequential
from keras import layers
import numpy as np
from six.moves import range
# Out:
# Using TensorFlow backend.

# %%
class colors:
    ok = '\033[92m'
    fail = '\033[91m'
    close = '\033[0m'

# %%
TRAINING_SIZE = 80000
DIGITS = 3
REVERSE = False
MAXLEN = DIGITS + 1 + DIGITS
chars = '0123456789-+ '
RNN = layers.LSTM
HIDDEN_SIZE = 128
BATCH_SIZE = 128
LAYERS = 1

# %%
class CharacterTable(object):
    def __init__(self, chars):
        self.chars = sorted(set(chars))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))
    
    def encode(self, C, num_rows): # ex: (C=43+7, num_rows=MAXLEN) or (C=50, num_rows=DIGITS + 1)
        x = np.zeros((num_rows, len(self.chars))) 
        for i, c in enumerate(C):
            x[i, self.char_indices[c]] = 1
        return x
    
    def decode(self, x, calc_argmax=True):
        if calc_argmax:
            x = x.argmax(axis=-1)
        return "".join(self.indices_char[i] for i in x)

# %%
ctable = CharacterTable(chars)

# %%
questions = []
expected = []
seen = set()      # 用來確保資料不會重複
print('Generating data...')
itor = 0
while len(questions) < TRAINING_SIZE:
    # f 是一個產生 1-3 位數亂數的 function，我覺得助教的寫法有點強
    f = lambda: int(''.join(np.random.choice(list('0123456789')) for i in range(np.random.randint(1, DIGITS + 1))))
    a, b = f(), f()
    key = tuple(sorted((a, b)))
    if key in seen: 
        continue
    seen.add(key)
    if(itor % 2):
        q = '{}-{}'.format(a, b) # 並沒有說小的數字放前面 大的數字放後面
        query = q + ' ' * (MAXLEN - len(q)) # 確保 input 長度一樣
        ans = str(a - b)
        ans += ' ' * (DIGITS + 1 - len(ans))
        if REVERSE:
            query = query[::-1] # [::-1] 會讓 query 相反過來，例如 "43+7   " 變成 "   7+34"，這個寫法我都不知道
        questions.append(query)
        expected.append(ans)
    else:
        q = '{}+{}'.format(a, b) # 並沒有說小的數字放前面 大的數字放後面
        query = q + ' ' * (MAXLEN - len(q)) # 確保 input 長度一樣
        ans = str(a + b)
        ans += ' ' * (DIGITS + 1 - len(ans))
        if REVERSE:
            query = query[::-1] # [::-1] 會讓 query 相反過來，例如 "43+7   " 變成 "   7+34"，這個寫法我都不知道
        questions.append(query)
        expected.append(ans)
    itor += 1
    
print('Total addition questions:', len(questions))
# Out:
# Generating data...
# Total addition questions: 80000

# %%
print(questions[:5], expected[:5])
# Out:
# ['61+7   ', '0-2    ', '18+63  ', '173-65 ', '2+30   '] ['68  ', '-2  ', '81  ', '108 ', '32  ']

# %%
print('Vectorization...')
x = np.zeros((len(questions), MAXLEN, len(chars)), dtype=np.bool) 
y = np.zeros((len(expected), DIGITS + 1, len(chars)), dtype=np.bool)
for i, sentence in enumerate(questions):
    x[i] = ctable.encode(sentence, MAXLEN) # 取每一筆 sentence 的意思，每一筆 sentence 是用 7 * 12 的矩陣表示
for i, sentence in enumerate(expected):
    y[i] = ctable.encode(sentence, DIGITS + 1)
# Out:
# Vectorization...

# %%
indices = np.arange(len(y))
np.random.shuffle(indices) # 原來把資料弄亂還可以這樣寫
x = x[indices]
y = y[indices]

# train_test_split
train_x = x[:20000]    # 20000
train_y = y[:20000]
test_x = x[20000:]     # 60000
test_y = y[20000:]

split_at = len(train_x) - len(train_x) // 10  # split_at=18000
(x_train, x_val) = train_x[:split_at], train_x[split_at:]
(y_train, y_val) = train_y[:split_at], train_y[split_at:]

print('Training Data:')
print(x_train.shape)
print(y_train.shape)

print('Validation Data:')
print(x_val.shape)
print(y_val.shape)

print('Testing Data:')
print(test_x.shape)
print(test_y.shape)
# Out:
# Training Data:
# (18000, 7, 13)
# (18000, 4, 13)
# Validation Data:
# (2000, 7, 13)
# (2000, 4, 13)
# Testing Data:
# (60000, 7, 13)
# (60000, 4, 13)

# %%
print('Build model...')

############################################
##### Build your own model here ############
############################################
model = Sequential()
# "Encode" the input sequence using an RNN, producing an output of HIDDEN_SIZE.
# Note: In a situation where your input sequences have a variable length,
# use input_shape=(None, num_feature).
# model.add(RNN(HIDDEN_SIZE, input_shape=(MAXLEN, len(chars)),return_sequences=True))
model.add(RNN(HIDDEN_SIZE, input_shape=(MAXLEN, len(chars))))
# As the decoder RNN's input, repeatedly provide with the last output of
# RNN for each time step. Repeat 'DIGITS + 1' times as that's the maximum
# length of output, e.g., when DIGITS=3, max output is 999+999=1998.
model.add(layers.RepeatVector(DIGITS + 1))
# model.add(layers.Lambda(lambda x: x[:,-(DIGITS + 1):,:]))
# The decoder RNN could be multiple layers stacked or a single layer.
for _ in range(LAYERS):
    # By setting return_sequences to True, return not only the last output but
    # all the outputs so far in the form of (num_samples, timesteps,
    # output_dim). This is necessary as TimeDistributed in the below expects
    # the first dimension to be the timesteps.
    model.add(RNN(HIDDEN_SIZE, return_sequences=True))

# Apply a dense layer to the every temporal slice of an input. For each of step
# of the output sequence, decide which character should be chosen.
model.add(layers.TimeDistributed(layers.Dense(len(chars), activation='softmax')))
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['acc'])
model.summary()
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_3 (LSTM)                (None, 128)               72704
# _________________________________________________________________
# repeat_vector_2 (RepeatVecto (None, 4, 128)            0
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 4, 128)            131584
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 4, 13)             1677
# =================================================================
# Total params: 205,965
# Trainable params: 205,965
# Non-trainable params: 0
# _________________________________________________________________

# %%
for iteration in range(200):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(x_train, y_train,
              batch_size=BATCH_SIZE,
              epochs=1,
              validation_data=(x_val, y_val))
    for i in range(10):
        ind = np.random.randint(0, len(x_val))
        rowx, rowy = x_val[np.array([ind])], y_val[np.array([ind])]
        preds = model.predict_classes(rowx, verbose=0)
        q = ctable.decode(rowx[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0], calc_argmax=False)
        '''
        print('Q', q[::-1] if REVERSE else q, end=' ')
        print('T', correct, end=' ')
        if correct == guess:
            print(colors.ok + '☑' + colors.close, end=' ')
        else:
            print(colors.fail + '☒' + colors.close, end=' ')
        print(guess)
        '''
# Out:
# --------------------------------------------------
# Iteration 0
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 116us/step - loss: 0.3421 - acc: 0.8866 - val_loss: 0.5894 - val_acc: 0.7669
#
# --------------------------------------------------
# Iteration 1
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 113us/step - loss: 0.3173 - acc: 0.9001 - val_loss: 0.5681 - val_acc: 0.7811
#
# --------------------------------------------------
# Iteration 2
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 114us/step - loss: 0.3032 - acc: 0.9052 - val_loss: 0.5525 - val_acc: 0.7844
#
# --------------------------------------------------
# Iteration 3
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 113us/step - loss: 0.2974 - acc: 0.9089 - val_loss: 0.5591 - val_acc: 0.7836
#
# --------------------------------------------------
# Iteration 4
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 114us/step - loss: 0.2867 - acc: 0.9127 - val_loss: 0.5600 - val_acc: 0.7811
#
# --------------------------------------------------
# Iteration 5
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 114us/step - loss: 0.2857 - acc: 0.9117 - val_loss: 0.5385 - val_acc: 0.7903
#
# --------------------------------------------------
# Iteration 6
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.2687 - acc: 0.9211 - val_loss: 0.5422 - val_acc: 0.7840
#
# --------------------------------------------------
# Iteration 7
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 124us/step - loss: 0.2638 - acc: 0.9214 - val_loss: 0.5381 - val_acc: 0.7945
#
# --------------------------------------------------
# Iteration 8
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.2536 - acc: 0.9258 - val_loss: 0.5310 - val_acc: 0.7953
#
# --------------------------------------------------
# Iteration 9
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.2397 - acc: 0.9338 - val_loss: 0.5115 - val_acc: 0.8061
#
# --------------------------------------------------
# Iteration 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.2409 - acc: 0.9309 - val_loss: 0.5178 - val_acc: 0.7999
#
# --------------------------------------------------
# Iteration 11
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.2392 - acc: 0.9311 - val_loss: 0.5460 - val_acc: 0.7902
#
# --------------------------------------------------
# Iteration 12
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.2510 - acc: 0.9241 - val_loss: 0.5203 - val_acc: 0.8013
#
# --------------------------------------------------
# Iteration 13
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.2129 - acc: 0.9440 - val_loss: 0.4895 - val_acc: 0.8116
#
# --------------------------------------------------
# Iteration 14
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.1996 - acc: 0.9510 - val_loss: 0.4959 - val_acc: 0.8146
#
# --------------------------------------------------
# Iteration 15
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.2014 - acc: 0.9479 - val_loss: 0.4848 - val_acc: 0.8092
#
# --------------------------------------------------
# Iteration 16
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 124us/step - loss: 0.1937 - acc: 0.9520 - val_loss: 0.4765 - val_acc: 0.8195
#
# --------------------------------------------------
# Iteration 17
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.1936 - acc: 0.9499 - val_loss: 0.4735 - val_acc: 0.8213
#
# --------------------------------------------------
# Iteration 18
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.1867 - acc: 0.9528 - val_loss: 0.5031 - val_acc: 0.8134
#
# --------------------------------------------------
# Iteration 19
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.1720 - acc: 0.9597 - val_loss: 0.4588 - val_acc: 0.8251
#
# --------------------------------------------------
# Iteration 20
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.1627 - acc: 0.9642 - val_loss: 0.4665 - val_acc: 0.8276
#
# --------------------------------------------------
# Iteration 21
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.1731 - acc: 0.9577 - val_loss: 0.5086 - val_acc: 0.8119
#
# --------------------------------------------------
# Iteration 22
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.1657 - acc: 0.9591 - val_loss: 0.4591 - val_acc: 0.8320
#
# --------------------------------------------------
# Iteration 23
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.1476 - acc: 0.9687 - val_loss: 0.4539 - val_acc: 0.8345
#
# --------------------------------------------------
# Iteration 24
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.1457 - acc: 0.9692 - val_loss: 0.4513 - val_acc: 0.8334
#
# --------------------------------------------------
# Iteration 25
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.1361 - acc: 0.9727 - val_loss: 0.4438 - val_acc: 0.8386
#
# --------------------------------------------------
# Iteration 26
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.1499 - acc: 0.9652 - val_loss: 0.5162 - val_acc: 0.8194
#
# --------------------------------------------------
# Iteration 27
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 124us/step - loss: 0.1627 - acc: 0.9556 - val_loss: 0.4745 - val_acc: 0.8256
#
# --------------------------------------------------
# Iteration 28
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.1317 - acc: 0.9725 - val_loss: 0.4810 - val_acc: 0.8297
#
# --------------------------------------------------
# Iteration 29
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.1701 - acc: 0.9550 - val_loss: 0.4447 - val_acc: 0.8375
#
# --------------------------------------------------
# Iteration 30
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 124us/step - loss: 0.1159 - acc: 0.9794 - val_loss: 0.4338 - val_acc: 0.8420
#
# --------------------------------------------------
# Iteration 31
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 124us/step - loss: 0.1071 - acc: 0.9824 - val_loss: 0.4259 - val_acc: 0.8448
#
# --------------------------------------------------
# Iteration 32
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.1027 - acc: 0.9838 - val_loss: 0.4396 - val_acc: 0.8405
#
# --------------------------------------------------
# Iteration 33
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.1007 - acc: 0.9833 - val_loss: 0.4383 - val_acc: 0.8417
#
# --------------------------------------------------
# Iteration 34
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0984 - acc: 0.9841 - val_loss: 0.4265 - val_acc: 0.8492
#
# --------------------------------------------------
# Iteration 35
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0944 - acc: 0.9849 - val_loss: 0.4360 - val_acc: 0.8415
#
# --------------------------------------------------
# Iteration 36
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0928 - acc: 0.9853 - val_loss: 0.4264 - val_acc: 0.8532
#
# --------------------------------------------------
# Iteration 37
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0940 - acc: 0.9836 - val_loss: 0.4420 - val_acc: 0.8474
#
# --------------------------------------------------
# Iteration 38
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.1343 - acc: 0.9665 - val_loss: 0.6151 - val_acc: 0.8049
#
# --------------------------------------------------
# Iteration 39
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.1449 - acc: 0.9587 - val_loss: 0.4219 - val_acc: 0.8519
#
# --------------------------------------------------
# Iteration 40
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0960 - acc: 0.9826 - val_loss: 0.4397 - val_acc: 0.8457
#
# --------------------------------------------------
# Iteration 41
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0856 - acc: 0.9856 - val_loss: 0.4253 - val_acc: 0.8520
#
# --------------------------------------------------
# Iteration 42
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0734 - acc: 0.9910 - val_loss: 0.4216 - val_acc: 0.8526
#
# --------------------------------------------------
# Iteration 43
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0692 - acc: 0.9920 - val_loss: 0.4161 - val_acc: 0.8537
#
# --------------------------------------------------
# Iteration 44
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0665 - acc: 0.9923 - val_loss: 0.4214 - val_acc: 0.8556
#
# --------------------------------------------------
# Iteration 45
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0658 - acc: 0.9919 - val_loss: 0.4193 - val_acc: 0.8579
#
# --------------------------------------------------
# Iteration 46
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0691 - acc: 0.9905 - val_loss: 0.4359 - val_acc: 0.8541
#
# --------------------------------------------------
# Iteration 47
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0715 - acc: 0.9888 - val_loss: 0.4329 - val_acc: 0.8560
#
# --------------------------------------------------
# Iteration 48
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0708 - acc: 0.9890 - val_loss: 0.5089 - val_acc: 0.8305
#
# --------------------------------------------------
# Iteration 49
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.1925 - acc: 0.9390 - val_loss: 0.5515 - val_acc: 0.8209
#
# --------------------------------------------------
# Iteration 50
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.1067 - acc: 0.9716 - val_loss: 0.4270 - val_acc: 0.8551
#
# --------------------------------------------------
# Iteration 51
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0770 - acc: 0.9856 - val_loss: 0.4134 - val_acc: 0.8625
#
# --------------------------------------------------
# Iteration 52
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0531 - acc: 0.9947 - val_loss: 0.4026 - val_acc: 0.8638
#
# --------------------------------------------------
# Iteration 53
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0473 - acc: 0.9962 - val_loss: 0.4110 - val_acc: 0.8600
#
# --------------------------------------------------
# Iteration 54
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0452 - acc: 0.9966 - val_loss: 0.4003 - val_acc: 0.8649
#
# --------------------------------------------------
# Iteration 55
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0435 - acc: 0.9967 - val_loss: 0.4046 - val_acc: 0.8663
#
# --------------------------------------------------
# Iteration 56
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 127us/step - loss: 0.0420 - acc: 0.9970 - val_loss: 0.4161 - val_acc: 0.8635
#
# --------------------------------------------------
# Iteration 57
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0432 - acc: 0.9961 - val_loss: 0.4156 - val_acc: 0.8638
#
# --------------------------------------------------
# Iteration 58
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0426 - acc: 0.9963 - val_loss: 0.4204 - val_acc: 0.8654
#
# --------------------------------------------------
# Iteration 59
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 124us/step - loss: 0.0686 - acc: 0.9857 - val_loss: 0.5509 - val_acc: 0.8304
#
# --------------------------------------------------
# Iteration 60
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 124us/step - loss: 0.1947 - acc: 0.9367 - val_loss: 0.4908 - val_acc: 0.8419
#
# --------------------------------------------------
# Iteration 61
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0753 - acc: 0.9832 - val_loss: 0.4376 - val_acc: 0.8582
#
# --------------------------------------------------
# Iteration 62
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0428 - acc: 0.9960 - val_loss: 0.4012 - val_acc: 0.8679
#
# --------------------------------------------------
# Iteration 63
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 124us/step - loss: 0.0354 - acc: 0.9976 - val_loss: 0.4043 - val_acc: 0.8691
#
# --------------------------------------------------
# Iteration 64
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0333 - acc: 0.9981 - val_loss: 0.4034 - val_acc: 0.8703
#
# --------------------------------------------------
# Iteration 65
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0315 - acc: 0.9982 - val_loss: 0.4043 - val_acc: 0.8698
#
# --------------------------------------------------
# Iteration 66
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0306 - acc: 0.9983 - val_loss: 0.4045 - val_acc: 0.8695
#
# --------------------------------------------------
# Iteration 67
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 117us/step - loss: 0.0295 - acc: 0.9985 - val_loss: 0.4157 - val_acc: 0.8669
#
# --------------------------------------------------
# Iteration 68
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0291 - acc: 0.9985 - val_loss: 0.4167 - val_acc: 0.8695
#
# --------------------------------------------------
# Iteration 69
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0284 - acc: 0.9987 - val_loss: 0.4185 - val_acc: 0.8676
#
# --------------------------------------------------
# Iteration 70
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.1468 - acc: 0.9542 - val_loss: 0.6195 - val_acc: 0.8130
#
# --------------------------------------------------
# Iteration 71
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.1036 - acc: 0.9677 - val_loss: 0.4717 - val_acc: 0.8501
#
# --------------------------------------------------
# Iteration 72
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0466 - acc: 0.9925 - val_loss: 0.4157 - val_acc: 0.8704
#
# --------------------------------------------------
# Iteration 73
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0292 - acc: 0.9984 - val_loss: 0.4106 - val_acc: 0.8714
#
# --------------------------------------------------
# Iteration 74
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0256 - acc: 0.9989 - val_loss: 0.4091 - val_acc: 0.8718
#
# --------------------------------------------------
# Iteration 75
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0242 - acc: 0.9991 - val_loss: 0.4111 - val_acc: 0.8732
#
# --------------------------------------------------
# Iteration 76
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0235 - acc: 0.9990 - val_loss: 0.4077 - val_acc: 0.8714
#
# --------------------------------------------------
# Iteration 77
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0227 - acc: 0.9991 - val_loss: 0.4126 - val_acc: 0.8739
#
# --------------------------------------------------
# Iteration 78
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0223 - acc: 0.9992 - val_loss: 0.4146 - val_acc: 0.8729
#
# --------------------------------------------------
# Iteration 79
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0220 - acc: 0.9991 - val_loss: 0.4193 - val_acc: 0.8699
#
# --------------------------------------------------
# Iteration 80
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0237 - acc: 0.9986 - val_loss: 0.4365 - val_acc: 0.8706
#
# --------------------------------------------------
# Iteration 81
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.1845 - acc: 0.9445 - val_loss: 0.6282 - val_acc: 0.8157
#
# --------------------------------------------------
# Iteration 82
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.1178 - acc: 0.9625 - val_loss: 0.4993 - val_acc: 0.8542
#
# --------------------------------------------------
# Iteration 83
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0670 - acc: 0.9843 - val_loss: 0.4393 - val_acc: 0.8666
#
# --------------------------------------------------
# Iteration 84
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0369 - acc: 0.9954 - val_loss: 0.4376 - val_acc: 0.8664
#
# --------------------------------------------------
# Iteration 85
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0236 - acc: 0.9991 - val_loss: 0.4114 - val_acc: 0.8745
#
# --------------------------------------------------
# Iteration 86
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0197 - acc: 0.9995 - val_loss: 0.4114 - val_acc: 0.8744
#
# --------------------------------------------------
# Iteration 87
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0184 - acc: 0.9995 - val_loss: 0.4100 - val_acc: 0.8770
#
# --------------------------------------------------
# Iteration 88
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0176 - acc: 0.9996 - val_loss: 0.4124 - val_acc: 0.8746
#
# --------------------------------------------------
# Iteration 89
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0170 - acc: 0.9995 - val_loss: 0.4154 - val_acc: 0.8762
#
# --------------------------------------------------
# Iteration 90
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0163 - acc: 0.9996 - val_loss: 0.4188 - val_acc: 0.8738
#
# --------------------------------------------------
# Iteration 91
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0158 - acc: 0.9997 - val_loss: 0.4191 - val_acc: 0.8736
#
# --------------------------------------------------
# Iteration 92
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0156 - acc: 0.9997 - val_loss: 0.4228 - val_acc: 0.8741
#
# --------------------------------------------------
# Iteration 93
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0152 - acc: 0.9997 - val_loss: 0.4227 - val_acc: 0.8709
#
# --------------------------------------------------
# Iteration 94
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0149 - acc: 0.9997 - val_loss: 0.4261 - val_acc: 0.8756
#
# --------------------------------------------------
# Iteration 95
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0146 - acc: 0.9997 - val_loss: 0.4332 - val_acc: 0.8732
#
# --------------------------------------------------
# Iteration 96
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0146 - acc: 0.9997 - val_loss: 0.4363 - val_acc: 0.8720
#
# --------------------------------------------------
# Iteration 97
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0147 - acc: 0.9996 - val_loss: 0.4415 - val_acc: 0.8686
#
# --------------------------------------------------
# Iteration 98
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.1466 - acc: 0.9605 - val_loss: 0.9819 - val_acc: 0.7564
#
# --------------------------------------------------
# Iteration 99
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.2092 - acc: 0.9325 - val_loss: 0.4752 - val_acc: 0.8602
#
# --------------------------------------------------
# Iteration 100
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 117us/step - loss: 0.0382 - acc: 0.9932 - val_loss: 0.4341 - val_acc: 0.8703
#
# --------------------------------------------------
# Iteration 101
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 117us/step - loss: 0.0199 - acc: 0.9992 - val_loss: 0.4203 - val_acc: 0.8740
#
# --------------------------------------------------
# Iteration 102
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 117us/step - loss: 0.0157 - acc: 0.9998 - val_loss: 0.4236 - val_acc: 0.8754
#
# --------------------------------------------------
# Iteration 103
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0141 - acc: 0.9998 - val_loss: 0.4246 - val_acc: 0.8740
#
# --------------------------------------------------
# Iteration 104
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0132 - acc: 0.9998 - val_loss: 0.4222 - val_acc: 0.8746
#
# --------------------------------------------------
# Iteration 105
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0125 - acc: 0.9999 - val_loss: 0.4247 - val_acc: 0.8733
#
# --------------------------------------------------
# Iteration 106
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0120 - acc: 0.9999 - val_loss: 0.4256 - val_acc: 0.8759
#
# --------------------------------------------------
# Iteration 107
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0115 - acc: 0.9999 - val_loss: 0.4256 - val_acc: 0.8756
#
# --------------------------------------------------
# Iteration 108
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0111 - acc: 0.9999 - val_loss: 0.4282 - val_acc: 0.8767
#
# --------------------------------------------------
# Iteration 109
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0108 - acc: 0.9999 - val_loss: 0.4287 - val_acc: 0.8762
#
# --------------------------------------------------
# Iteration 110
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0106 - acc: 0.9999 - val_loss: 0.4309 - val_acc: 0.8746
#
# --------------------------------------------------
# Iteration 111
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0103 - acc: 0.9999 - val_loss: 0.4366 - val_acc: 0.8726
#
# --------------------------------------------------
# Iteration 112
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0099 - acc: 0.9999 - val_loss: 0.4355 - val_acc: 0.8758
#
# --------------------------------------------------
# Iteration 113
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0098 - acc: 0.9999 - val_loss: 0.4406 - val_acc: 0.8754
#
# --------------------------------------------------
# Iteration 114
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0096 - acc: 0.9998 - val_loss: 0.4476 - val_acc: 0.8733
#
# --------------------------------------------------
# Iteration 115
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.2197 - acc: 0.9358 - val_loss: 0.7592 - val_acc: 0.8042
#
# --------------------------------------------------
# Iteration 116
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 125us/step - loss: 0.1290 - acc: 0.9567 - val_loss: 0.4926 - val_acc: 0.8559
#
# --------------------------------------------------
# Iteration 117
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 129us/step - loss: 0.0418 - acc: 0.9908 - val_loss: 0.4428 - val_acc: 0.8721
#
# --------------------------------------------------
# Iteration 118
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 126us/step - loss: 0.0223 - acc: 0.9976 - val_loss: 0.4265 - val_acc: 0.8740
#
# --------------------------------------------------
# Iteration 119
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 125us/step - loss: 0.0127 - acc: 0.9999 - val_loss: 0.4202 - val_acc: 0.8762
#
# --------------------------------------------------
# Iteration 120
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0109 - acc: 0.9999 - val_loss: 0.4195 - val_acc: 0.8764
#
# --------------------------------------------------
# Iteration 121
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0103 - acc: 0.9999 - val_loss: 0.4228 - val_acc: 0.8771
#
# --------------------------------------------------
# Iteration 122
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0096 - acc: 1.0000 - val_loss: 0.4269 - val_acc: 0.8767
#
# --------------------------------------------------
# Iteration 123
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0092 - acc: 0.9999 - val_loss: 0.4285 - val_acc: 0.8745
#
# --------------------------------------------------
# Iteration 124
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0088 - acc: 1.0000 - val_loss: 0.4286 - val_acc: 0.8753
#
# --------------------------------------------------
# Iteration 125
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 125us/step - loss: 0.0085 - acc: 1.0000 - val_loss: 0.4277 - val_acc: 0.8779
#
# --------------------------------------------------
# Iteration 126
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0082 - acc: 1.0000 - val_loss: 0.4315 - val_acc: 0.8776
#
# --------------------------------------------------
# Iteration 127
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0080 - acc: 0.9999 - val_loss: 0.4330 - val_acc: 0.8784
#
# --------------------------------------------------
# Iteration 128
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0077 - acc: 1.0000 - val_loss: 0.4332 - val_acc: 0.8762
#
# --------------------------------------------------
# Iteration 129
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0075 - acc: 1.0000 - val_loss: 0.4379 - val_acc: 0.8779
#
# --------------------------------------------------
# Iteration 130
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0073 - acc: 1.0000 - val_loss: 0.4349 - val_acc: 0.8782
#
# --------------------------------------------------
# Iteration 131
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0071 - acc: 1.0000 - val_loss: 0.4454 - val_acc: 0.8763
#
# --------------------------------------------------
# Iteration 132
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0069 - acc: 1.0000 - val_loss: 0.4420 - val_acc: 0.8765
#
# --------------------------------------------------
# Iteration 133
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0068 - acc: 0.9999 - val_loss: 0.4562 - val_acc: 0.8738
#
# --------------------------------------------------
# Iteration 134
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.2812 - acc: 0.9151 - val_loss: 0.6778 - val_acc: 0.8216
#
# --------------------------------------------------
# Iteration 135
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 117us/step - loss: 0.0963 - acc: 0.9685 - val_loss: 0.5015 - val_acc: 0.8572
#
# --------------------------------------------------
# Iteration 136
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0274 - acc: 0.9956 - val_loss: 0.4378 - val_acc: 0.8727
#
# --------------------------------------------------
# Iteration 137
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0132 - acc: 0.9996 - val_loss: 0.4308 - val_acc: 0.8771
#
# --------------------------------------------------
# Iteration 138
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0098 - acc: 0.9999 - val_loss: 0.4242 - val_acc: 0.8801
#
# --------------------------------------------------
# Iteration 139
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0086 - acc: 1.0000 - val_loss: 0.4241 - val_acc: 0.8790
#
# --------------------------------------------------
# Iteration 140
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0080 - acc: 1.0000 - val_loss: 0.4237 - val_acc: 0.8793
#
# --------------------------------------------------
# Iteration 141
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0077 - acc: 1.0000 - val_loss: 0.4253 - val_acc: 0.8794
#
# --------------------------------------------------
# Iteration 142
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0073 - acc: 1.0000 - val_loss: 0.4306 - val_acc: 0.8794
#
# --------------------------------------------------
# Iteration 143
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0070 - acc: 1.0000 - val_loss: 0.4298 - val_acc: 0.8795
#
# --------------------------------------------------
# Iteration 144
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0067 - acc: 1.0000 - val_loss: 0.4314 - val_acc: 0.8801
#
# --------------------------------------------------
# Iteration 145
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0064 - acc: 1.0000 - val_loss: 0.4316 - val_acc: 0.8790
#
# --------------------------------------------------
# Iteration 146
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0062 - acc: 1.0000 - val_loss: 0.4353 - val_acc: 0.8791
#
# --------------------------------------------------
# Iteration 147
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0060 - acc: 1.0000 - val_loss: 0.4378 - val_acc: 0.8790
#
# --------------------------------------------------
# Iteration 148
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0058 - acc: 1.0000 - val_loss: 0.4390 - val_acc: 0.8810
#
# --------------------------------------------------
# Iteration 149
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0056 - acc: 1.0000 - val_loss: 0.4409 - val_acc: 0.8783
#
# --------------------------------------------------
# Iteration 150
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0055 - acc: 1.0000 - val_loss: 0.4422 - val_acc: 0.8797
#
# --------------------------------------------------
# Iteration 151
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0054 - acc: 1.0000 - val_loss: 0.4451 - val_acc: 0.8791
#
# --------------------------------------------------
# Iteration 152
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 134us/step - loss: 0.0052 - acc: 1.0000 - val_loss: 0.4486 - val_acc: 0.8782
#
# --------------------------------------------------
# Iteration 153
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 126us/step - loss: 0.0051 - acc: 1.0000 - val_loss: 0.4495 - val_acc: 0.8764
#
# --------------------------------------------------
# Iteration 154
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 124us/step - loss: 0.0049 - acc: 1.0000 - val_loss: 0.4511 - val_acc: 0.8772
#
# --------------------------------------------------
# Iteration 155
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0048 - acc: 1.0000 - val_loss: 0.4529 - val_acc: 0.8792
#
# --------------------------------------------------
# Iteration 156
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 126us/step - loss: 0.0047 - acc: 1.0000 - val_loss: 0.4558 - val_acc: 0.8782
#
# --------------------------------------------------
# Iteration 157
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0052 - acc: 0.9999 - val_loss: 0.4773 - val_acc: 0.8713
#
# --------------------------------------------------
# Iteration 158
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.3526 - acc: 0.9003 - val_loss: 0.6052 - val_acc: 0.8388
#
# --------------------------------------------------
# Iteration 159
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0857 - acc: 0.9719 - val_loss: 0.4908 - val_acc: 0.8620
#
# --------------------------------------------------
# Iteration 160
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0257 - acc: 0.9950 - val_loss: 0.4410 - val_acc: 0.8724
#
# --------------------------------------------------
# Iteration 161
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 129us/step - loss: 0.0200 - acc: 0.9967 - val_loss: 0.4498 - val_acc: 0.8707
#
# --------------------------------------------------
# Iteration 162
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 128us/step - loss: 0.0120 - acc: 0.9992 - val_loss: 0.4244 - val_acc: 0.8776
#
# --------------------------------------------------
# Iteration 163
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0079 - acc: 0.9998 - val_loss: 0.4309 - val_acc: 0.8784
#
# --------------------------------------------------
# Iteration 164
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 124us/step - loss: 0.0079 - acc: 0.9998 - val_loss: 0.4306 - val_acc: 0.8773
#
# --------------------------------------------------
# Iteration 165
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0068 - acc: 0.9999 - val_loss: 0.4248 - val_acc: 0.8796
#
# --------------------------------------------------
# Iteration 166
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 125us/step - loss: 0.0058 - acc: 1.0000 - val_loss: 0.4264 - val_acc: 0.8797
#
# --------------------------------------------------
# Iteration 167
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 125us/step - loss: 0.0054 - acc: 1.0000 - val_loss: 0.4292 - val_acc: 0.8788
#
# --------------------------------------------------
# Iteration 168
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0051 - acc: 1.0000 - val_loss: 0.4289 - val_acc: 0.8800
#
# --------------------------------------------------
# Iteration 169
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0049 - acc: 1.0000 - val_loss: 0.4300 - val_acc: 0.8792
#
# --------------------------------------------------
# Iteration 170
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0047 - acc: 1.0000 - val_loss: 0.4328 - val_acc: 0.8792
#
# --------------------------------------------------
# Iteration 171
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 128us/step - loss: 0.0046 - acc: 1.0000 - val_loss: 0.4321 - val_acc: 0.8794
#
# --------------------------------------------------
# Iteration 172
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 128us/step - loss: 0.0044 - acc: 1.0000 - val_loss: 0.4358 - val_acc: 0.8780
#
# --------------------------------------------------
# Iteration 173
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0043 - acc: 1.0000 - val_loss: 0.4370 - val_acc: 0.8805
#
# --------------------------------------------------
# Iteration 174
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0041 - acc: 1.0000 - val_loss: 0.4402 - val_acc: 0.8809
#
# --------------------------------------------------
# Iteration 175
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0040 - acc: 1.0000 - val_loss: 0.4409 - val_acc: 0.8821
#
# --------------------------------------------------
# Iteration 176
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0039 - acc: 1.0000 - val_loss: 0.4443 - val_acc: 0.8789
#
# --------------------------------------------------
# Iteration 177
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0038 - acc: 1.0000 - val_loss: 0.4444 - val_acc: 0.8795
#
# --------------------------------------------------
# Iteration 178
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0037 - acc: 1.0000 - val_loss: 0.4415 - val_acc: 0.8799
#
# --------------------------------------------------
# Iteration 179
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0036 - acc: 1.0000 - val_loss: 0.4476 - val_acc: 0.8798
#
# --------------------------------------------------
# Iteration 180
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0035 - acc: 1.0000 - val_loss: 0.4514 - val_acc: 0.8799
#
# --------------------------------------------------
# Iteration 181
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.4547 - val_acc: 0.8799
#
# --------------------------------------------------
# Iteration 182
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.4540 - val_acc: 0.8805
#
# --------------------------------------------------
# Iteration 183
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0032 - acc: 1.0000 - val_loss: 0.4592 - val_acc: 0.8783
#
# --------------------------------------------------
# Iteration 184
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 119us/step - loss: 0.0096 - acc: 0.9979 - val_loss: 0.7362 - val_acc: 0.8231
#
# --------------------------------------------------
# Iteration 185
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.3794 - acc: 0.8938 - val_loss: 0.6091 - val_acc: 0.8364
#
# --------------------------------------------------
# Iteration 186
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0598 - acc: 0.9820 - val_loss: 0.6189 - val_acc: 0.8440
#
# --------------------------------------------------
# Iteration 187
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0340 - acc: 0.9917 - val_loss: 0.4870 - val_acc: 0.8661
#
# --------------------------------------------------
# Iteration 188
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0132 - acc: 0.9985 - val_loss: 0.4489 - val_acc: 0.8750
#
# --------------------------------------------------
# Iteration 189
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 123us/step - loss: 0.0067 - acc: 0.9999 - val_loss: 0.4421 - val_acc: 0.8788
#
# --------------------------------------------------
# Iteration 190
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 120us/step - loss: 0.0055 - acc: 1.0000 - val_loss: 0.4408 - val_acc: 0.8771
#
# --------------------------------------------------
# Iteration 191
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 122us/step - loss: 0.0050 - acc: 1.0000 - val_loss: 0.4410 - val_acc: 0.8778
#
# --------------------------------------------------
# Iteration 192
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 125us/step - loss: 0.0046 - acc: 1.0000 - val_loss: 0.4409 - val_acc: 0.8789
#
# --------------------------------------------------
# Iteration 193
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0044 - acc: 1.0000 - val_loss: 0.4418 - val_acc: 0.8779
#
# --------------------------------------------------
# Iteration 194
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 128us/step - loss: 0.0042 - acc: 1.0000 - val_loss: 0.4422 - val_acc: 0.8796
#
# --------------------------------------------------
# Iteration 195
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 130us/step - loss: 0.0040 - acc: 1.0000 - val_loss: 0.4424 - val_acc: 0.8787
#
# --------------------------------------------------
# Iteration 196
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 121us/step - loss: 0.0038 - acc: 1.0000 - val_loss: 0.4431 - val_acc: 0.8800
#
# --------------------------------------------------
# Iteration 197
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 117us/step - loss: 0.0037 - acc: 1.0000 - val_loss: 0.4455 - val_acc: 0.8789
#
# --------------------------------------------------
# Iteration 198
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0036 - acc: 1.0000 - val_loss: 0.4472 - val_acc: 0.8794
#
# --------------------------------------------------
# Iteration 199
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 2s 118us/step - loss: 0.0034 - acc: 1.0000 - val_loss: 0.4466 - val_acc: 0.8788

# %%
print("MSG : Prediction")
#####################################################
## Try to test and evaluate your model ##############
## ex. test_x = ["555+175", "860+7  ", "340+29 "]
## ex. test_y = ["730 ", "867 ", "369 "] 
#####################################################
loss, acc = model.evaluate(test_x,test_y)
print("Loss:",loss)
print("Accuracy:",acc)
# Out:
# MSG : Prediction
# 60000/60000 [==============================] - 4s 69us/step
# Loss: 0.454495231060187
# Accuracy: 0.8840083333333333
